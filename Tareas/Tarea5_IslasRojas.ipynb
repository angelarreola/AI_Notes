# %% [markdown]
# ## Tarea 5 - Introspección | Detección de elementos específicos (Islas Rojas)
#     Ensayo | Solucion de Ángel Arreola

# %% [markdown]
# #### Introducción y Contexto del Código para la Detección de Islas Rojas en Imágenes
# Este código para la detección de objetos de color rojo en imágenes digitales es una evolución del algoritmo previamente desarrollado para identificar islas en imágenes. Tomando como base el enfoque y las técnicas utilizadas en el ejemplo anterior, este nuevo algoritmo se adapta y mejora para enfocarse específicamente en la detección de objetos rojos. Al igual que el código original, emplea la biblioteca OpenCV y NumPy, aprovechando el potencial de Python en el procesamiento de imágenes y la visión por computadora. Sin embargo, introduce cambios significativos en la identificación del color y el tratamiento de los datos de la imagen, reflejando un avance en la complejidad y la especificidad de la tarea de detección.
#
# ![Alt text](imagenIslasRojas.png)

# %% [markdown]
# ### Análisis y Teoría detrás del Código para la Detección de Islas Rojas en Imágenes
#
# El código presentado implementa un algoritmo para detectar y localizar objetos de color rojo en una imagen digital, utilizando la biblioteca OpenCV y NumPy en Python. Este algoritmo se basa en el concepto de Flood Fill y la manipulación del espacio de color HSV (Hue, Saturation, Value). A continuación, se detallan los aspectos teóricos y prácticos clave de esta solución.
#
# #### 1. Espacio de Color HSV
#
# - **Selección del Espacio de Color:**
#   - El color de los objetos a detectar se define en el espacio HSV, que es más efectivo que el espacio RGB para la identificación de colores debido a su capacidad para separar la información de color (matiz y saturación) de la luminancia (valor).
#
# - **Definición del Rojo en HSV:**
#   - El rojo, al estar en los extremos del espectro de colores en HSV, se define en dos rangos: uno cerca del principio (0-10) y otro cerca del final (170-180) del eje de matiz.
#
# #### 2. Flood Fill para la Detección de Objetos
#
# - **Funcionamiento del Flood Fill:**
# El algoritmo Flood Fill comienza en un píxel (semilla) y se expande a los píxeles vecinos, agrupando aquellos que cumplen con un criterio específico, en este caso, estar dentro del rango de color rojo definido.
#
# - **Implementación en el Código:**
# La función "flood_fill" recibe el espacio de color HSV de la imagen, un punto semilla, los rangos de color rojo, un array de píxeles visitados y un tamaño mínimo para los objetos. Recorre los píxeles vecinos, verificando si están dentro del rango de color rojo y si ya han sido visitados, agregándolos a la lista de píxeles del objeto.
#
# #### 3. Validación de Color
#
# - **Función "is_valid_color":**
# Esta función verifica si un píxel está dentro del rango de color rojo definido en HSV. Facilita la identificación de píxeles que pertenecen a los objetos de interés.
#
# #### 4. Localización de Objetos y Umbral de Tamaño
#
# - **Función "find_objects":**
# Convierte la imagen al espacio HSV, recorre cada píxel y aplica "flood_fill" si el píxel es rojo y no ha sido visitado. Calcula el centroide de los píxeles que forman un objeto, considerando solo aquellos con un tamaño mayor al mínimo definido.
#
# #### 5. Procesamiento y Visualización Final
#
# - **Detección y Dibujo de Objetos:**
# El código carga la imagen, aplica "find_objects" para cada rango de rojo en HSV, dibuja círculos en los centros de los objetos detectados y muestra la imagen final.

# %%
import cv2
import numpy as np

def is_valid_color(hsv_pixel, lower_red, upper_red):
    """ Verifica si el color HSV está dentro del rango del rojo. """
    return all(lower_red <= hsv_pixel) and all(hsv_pixel <= upper_red)

def flood_fill(hsv, seed_point, lower_red, upper_red, visited, min_size):
    rows, cols = hsv.shape[:2]
    object_pixels = []
    queue = [seed_point]

    while queue:
        x, y = queue.pop(0)
        if visited[y, x]:
            continue

        current_color = hsv[y, x]
        if is_valid_color(current_color, lower_red, upper_red):
            visited[y, x] = True
            object_pixels.append((x, y))

            # Agregar vecinos a la cola
            for dx, dy in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
                nx, ny = x + dx, y + dy
                if 0 <= nx < cols and 0 <= ny < rows and not visited[ny, nx]:
                    queue.append((nx, ny))

    if len(object_pixels) >= min_size:
        return object_pixels
    return []

def find_objects(image, lower_red, upper_red, min_size):
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    visited = np.zeros(hsv.shape[:2], dtype=bool)
    object_centers = []

    for y in range(hsv.shape[0]):
        for x in range(hsv.shape[1]):
            if is_valid_color(hsv[y, x], lower_red, upper_red) and not visited[y, x]:
                object_pixels = flood_fill(hsv, (x, y), lower_red, upper_red, visited, min_size)
                if object_pixels:
                    object_center = np.mean(object_pixels, axis=0)
                    object_centers.append((int(object_center[0]), int(object_center[1])))

    return object_centers

# Definir el tamaño mínimo para los objetos detectados (por ejemplo, 30 píxeles)
min_size = 20

# Definir los rangos de rojo en HSV
lower_red1 = np.array([0, 150, 50])
upper_red1 = np.array([10, 255, 255])
lower_red2 = np.array([170, 150, 50])
upper_red2 = np.array([180, 255, 255])


# Cargar la imagen
image_path = 'C:\\Users\\angel\\Desktop\\AI\\Tareas\\imagenIslasRojas.png'
image = cv2.imread(image_path)

# Encontrar los objetos rojos utilizando flood fill
object_centers = find_objects(image, lower_red1, upper_red1, min_size)
object_centers.extend(find_objects(image, lower_red2, upper_red2, min_size))

# Mostrar las coordenadas de los centros de los objetos rojos detectados
for idx, center in enumerate(object_centers):
    print(f"Centro del objeto rojo {idx+1}: {center}")

# Dibujar círculos amarillos en los centros de los objetos rojos
for center in object_centers:
    cv2.circle(image, center=center, radius=5, color=(0, 255, 255), thickness=2)

# Guardar y mostrar la imagen resultante
output_image_path = 'C:\\Users\\angel\\Desktop\\AI\\Tareas\\detected_red_objects.png'
cv2.imwrite(output_image_path, image)
cv2.imshow('Detected Red Objects', image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Centro del objeto rojo 1: (446, 16)
# Centro del objeto rojo 2: (582, 26)
# Centro del objeto rojo 3: (604, 22)
# Centro del objeto rojo 4: (557, 27)
# Centro del objeto rojo 5: (442, 25)
# Centro del objeto rojo 6: (128, 43)
# Centro del objeto rojo 7: (24, 33)
# Centro del objeto rojo 8: (309, 36)
# Centro del objeto rojo 9: (251, 39)
# Centro del objeto rojo 10: (261, 47)
# Centro del objeto rojo 11: (177, 56)
# Centro del objeto rojo 12: (151, 59)
# Centro del objeto rojo 13: (214, 54)
# Centro del objeto rojo 14: (260, 58)
# Centro del objeto rojo 15: (200, 60)
# Centro del objeto rojo 16: (167, 73)
# Centro del objeto rojo 17: (287, 65)
# Centro del objeto rojo 18: (107, 65)
# Centro del objeto rojo 19: (194, 67)
# Centro del objeto rojo 20: (338, 66)
# Centro del objeto rojo 21: (135, 70)
# Centro del objeto rojo 22: (105, 71)
# Centro del objeto rojo 23: (286, 75)
# Centro del objeto rojo 24: (126, 80)
# Centro del objeto rojo 25: (208, 80)
# Centro del objeto rojo 26: (142, 83)
# Centro del objeto rojo 27: (245, 109)
# Centro del objeto rojo 28: (315, 127)
# Centro del objeto rojo 29: (297, 134)
# Centro del objeto rojo 30: (334, 141)
# Centro del objeto rojo 31: (303, 141)
# Centro del objeto rojo 32: (596, 145)
# Centro del objeto rojo 33: (611, 147)
# Centro del objeto rojo 34: (312, 148)
# Centro del objeto rojo 35: (316, 160)
# Centro del objeto rojo 36: (591, 157)
# Centro del objeto rojo 37: (13, 164)
# Centro del objeto rojo 38: (305, 159)
# Centro del objeto rojo 39: (582, 163)
# Centro del objeto rojo 40: (328, 159)
# Centro del objeto rojo 41: (504, 175)
# Centro del objeto rojo 42: (589, 173)
# Centro del objeto rojo 43: (601, 181)
# Centro del objeto rojo 44: (579, 196)
# Centro del objeto rojo 45: (219, 193)
# Centro del objeto rojo 46: (238, 191)
# Centro del objeto rojo 47: (460, 216)
# Centro del objeto rojo 48: (235, 229)
# Centro del objeto rojo 49: (476, 217)
# Centro del objeto rojo 50: (26, 232)
# Centro del objeto rojo 51: (583, 225)
# Centro del objeto rojo 52: (194, 232)
# Centro del objeto rojo 53: (162, 232)
# Centro del objeto rojo 54: (567, 239)
# Centro del objeto rojo 55: (137, 238)
# Centro del objeto rojo 56: (155, 244)
# Centro del objeto rojo 57: (58, 250)
# Centro del objeto rojo 58: (130, 250)
# Centro del objeto rojo 59: (140, 247)
# Centro del objeto rojo 60: (52, 256)
# Centro del objeto rojo 61: (16, 260)
# Centro del objeto rojo 62: (24, 261)
# Centro del objeto rojo 63: (179, 263)
# Centro del objeto rojo 64: (24, 270)
# Centro del objeto rojo 65: (470, 284)
# Centro del objeto rojo 66: (488, 289)
# Centro del objeto rojo 67: (494, 284)
# Centro del objeto rojo 68: (509, 288)
# Centro del objeto rojo 69: (106, 297)
# Centro del objeto rojo 70: (15, 297)
# Centro del objeto rojo 71: (78, 304)
# Centro del objeto rojo 72: (597, 298)
# Centro del objeto rojo 73: (115, 300)
# Centro del objeto rojo 74: (614, 303)
# Centro del objeto rojo 75: (600, 305)
# Centro del objeto rojo 76: (67, 307)
# Centro del objeto rojo 77: (129, 315)
# Centro del objeto rojo 78: (78, 317)
# Centro del objeto rojo 79: (151, 324)
# Centro del objeto rojo 80: (139, 321)
# Centro del objeto rojo 81: (480, 335)
# Centro del objeto rojo 82: (468, 335)
# Centro del objeto rojo 83: (225, 342)
# Centro del objeto rojo 84: (240, 352)
# Centro del objeto rojo 85: (257, 342)
# Centro del objeto rojo 86: (469, 345)
# Centro del objeto rojo 87: (481, 354)
# Centro del objeto rojo 88: (487, 345)
# Centro del objeto rojo 89: (258, 349)
# Centro del objeto rojo 90: (405, 358)
# Centro del objeto rojo 91: (425, 369)
# Centro del objeto rojo 92: (390, 371)
# Centro del objeto rojo 93: (422, 374)
# Centro del objeto rojo 94: (385, 376)
# Centro del objeto rojo 95: (440, 388)
# Centro del objeto rojo 96: (449, 388)
# Centro del objeto rojo 97: (407, 386)
# Centro del objeto rojo 98: (540, 408)
# Centro del objeto rojo 99: (564, 415)
# Centro del objeto rojo 100: (24, 419)
# Centro del objeto rojo 101: (576, 420)
# Centro del objeto rojo 102: (34, 435)
# Centro del objeto rojo 103: (94, 456)
# Centro del objeto rojo 104: (79, 462)
# Centro del objeto rojo 105: (50, 471)
# Centro del objeto rojo 106: (36, 469)
# Centro del objeto rojo 107: (79, 480)
# Centro del objeto rojo 108: (65, 482)
# Centro del objeto rojo 109: (601, 481)
# Centro del objeto rojo 110: (40, 487)
# Centro del objeto rojo 111: (597, 495)
# Centro del objeto rojo 112: (50, 490)
# Centro del objeto rojo 113: (124, 497)
# Centro del objeto rojo 114: (118, 502)
# Centro del objeto rojo 115: (588, 504)
# Centro del objeto rojo 116: (397, 507)
# Centro del objeto rojo 117: (587, 508)
# Centro del objeto rojo 118: (433, 518)
# Centro del objeto rojo 119: (587, 517)
# Centro del objeto rojo 120: (387, 521)
# Centro del objeto rojo 121: (582, 523)
# Centro del objeto rojo 122: (415, 527)
# Centro del objeto rojo 123: (100, 572)
# Centro del objeto rojo 124: (231, 585)
# Centro del objeto rojo 125: (422, 593)
# Centro del objeto rojo 126: (446, 606)
# Centro del objeto rojo 127: (410, 602)
# Centro del objeto rojo 128: (421, 605)
# Centro del objeto rojo 129: (407, 614)
# Centro del objeto rojo 130: (347, 612)
# Centro del objeto rojo 131: (172, 617)
# Centro del objeto rojo 132: (606, 619)
# Centro del objeto rojo 133: (443, 19)
# Centro del objeto rojo 134: (578, 22)
# Centro del objeto rojo 135: (590, 20)
# Centro del objeto rojo 136: (602, 19)
# Centro del objeto rojo 137: (565, 30)
# Centro del objeto rojo 138: (549, 33)
# Centro del objeto rojo 139: (190, 44)
# Centro del objeto rojo 140: (255, 40)
# Centro del objeto rojo 141: (157, 66)
# Centro del objeto rojo 142: (196, 62)
# Centro del objeto rojo 143: (263, 54)
# Centro del objeto rojo 144: (219, 60)
# Centro del objeto rojo 145: (170, 66)
# Centro del objeto rojo 146: (141, 65)
# Centro del objeto rojo 147: (339, 62)
# Centro del objeto rojo 148: (291, 70)
# Centro del objeto rojo 149: (104, 68)
# Centro del objeto rojo 150: (130, 75)
# Centro del objeto rojo 151: (162, 85)
# Centro del objeto rojo 152: (248, 104)
# Centro del objeto rojo 153: (310, 119)
# Centro del objeto rojo 154: (317, 142)
# Centro del objeto rojo 155: (592, 159)
# Centro del objeto rojo 156: (617, 151)
# Centro del objeto rojo 157: (11, 156)
# Centro del objeto rojo 158: (504, 177)
# Centro del objeto rojo 159: (603, 181)
# Centro del objeto rojo 160: (223, 192)
# Centro del objeto rojo 161: (466, 210)
# Centro del objeto rojo 162: (24, 250)
# Centro del objeto rojo 163: (144, 246)
# Centro del objeto rojo 164: (57, 242)
# Centro del objeto rojo 165: (55, 253)
# Centro del objeto rojo 166: (176, 265)
# Centro del objeto rojo 167: (16, 290)
# Centro del objeto rojo 168: (467, 286)
# Centro del objeto rojo 169: (491, 286)
# Centro del objeto rojo 170: (512, 287)
# Centro del objeto rojo 171: (73, 305)
# Centro del objeto rojo 172: (110, 298)
# Centro del objeto rojo 173: (608, 299)
# Centro del objeto rojo 174: (124, 316)
# Centro del objeto rojo 175: (135, 320)
# Centro del objeto rojo 176: (146, 321)
# Centro del objeto rojo 177: (224, 335)
# Centro del objeto rojo 178: (482, 345)
# Centro del objeto rojo 179: (262, 338)
# Centro del objeto rojo 180: (231, 345)
# Centro del objeto rojo 181: (250, 346)
# Centro del objeto rojo 182: (237, 353)
# Centro del objeto rojo 183: (390, 365)
# Centro del objeto rojo 184: (91, 363)
# Centro del objeto rojo 185: (421, 366)
# Centro del objeto rojo 186: (48, 366)
# Centro del objeto rojo 187: (102, 368)
# Centro del objeto rojo 188: (459, 377)
# Centro del objeto rojo 189: (468, 378)
# Centro del objeto rojo 190: (452, 378)
# Centro del objeto rojo 191: (405, 378)
# Centro del objeto rojo 192: (31, 427)
# Centro del objeto rojo 193: (39, 472)
# Centro del objeto rojo 194: (48, 463)
# Centro del objeto rojo 195: (90, 470)
# Centro del objeto rojo 196: (78, 470)
# Centro del objeto rojo 197: (64, 475)
# Centro del objeto rojo 198: (50, 482)
# Centro del objeto rojo 199: (63, 488)
# Centro del objeto rojo 200: (76, 482)
# Centro del objeto rojo 201: (602, 487)
# Centro del objeto rojo 202: (123, 503)
# Centro del objeto rojo 203: (594, 499)
# Centro del objeto rojo 204: (112, 517)
# Centro del objeto rojo 205: (432, 519)
# Centro del objeto rojo 206: (239, 544)
# Centro del objeto rojo 207: (96, 570)
# Centro del objeto rojo 208: (237, 584)
# Centro del objeto rojo 209: (408, 606)
# Centro del objeto rojo 210: (448, 596)
# Centro del objeto rojo 211: (349, 607)
# Centro del objeto rojo 212: (368, 609)
# Centro del objeto rojo 213: (444, 616)
# Centro del objeto rojo 214: (176, 615)
# Centro del objeto rojo 215: (608, 621)

# %% [markdown]
# #### Conclusión
# Este código ilustra una aplicación efectiva de Flood Fill y la manipulación del espacio de color HSV para la detección de objetos específicos en imágenes. La elección de HSV para la definición del color y el uso de Flood Fill para la agrupación de píxeles ofrecen una metodología robusta y precisa para identificar y localizar objetos de color rojo en una imagen. Este enfoque demuestra cómo los conceptos de la visión por computadora y la ciencia de la computación pueden combinarse para resolver problemas complejos de procesamiento de imágenes.
#
# ![Alt text](detected_red_objects%20copy.png)

# %% [markdown]
# ### Version usando Find Contours

# %%
import cv2
import numpy as np

def find_red_objects(image):
    # Convertir la imagen a espacio de color HSV
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    # Ajustar los rangos de color rojo para capturar solo los tonos rojos
    # HSV values: [Hue, Saturation, Value]
    lower_red1 = np.array([0, 150, 50])  # Ajustar la saturación y el valor para ser más específico para el rojo
    upper_red1 = np.array([10, 255, 255])
    lower_red2 = np.array([170, 150, 50])
    upper_red2 = np.array([180, 255, 255])

    # Crear dos máscaras para el rango de rojo y luego combinarlas
    mask1 = cv2.inRange(hsv_image, lower_red1, upper_red1)
    mask2 = cv2.inRange(hsv_image, lower_red2, upper_red2)
    red_mask = cv2.bitwise_or(mask1, mask2)

    # Usar dilatación para conectar componentes rojos
    kernel = np.ones((3,3), np.uint8)
    red_mask_dilated = cv2.dilate(red_mask, kernel, iterations=2)

    # Encontrar contornos en la máscara roja dilatada
    contours, _ = cv2.findContours(red_mask_dilated, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Convertir la imagen a escala de grises para el fondo
    grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    grey_image_colored = cv2.cvtColor(grey_image, cv2.COLOR_GRAY2BGR)

    # Pintar los objetos rojos en la imagen en escala de grises
    colored_objects_mask = np.zeros_like(image)
    cv2.drawContours(colored_objects_mask, contours, -1, (255, 255, 255), cv2.FILLED)
    grey_image_colored[colored_objects_mask == 255] = image[colored_objects_mask == 255]

    red_objects_centers = []

    # Calcular el centroide de cada contorno rojo detectado y dibujar un círculo amarillo
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] > 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            red_objects_centers.append((cX, cY))
            cv2.circle(grey_image_colored, (cX, cY), 7, (0, 255, 255), -1)  # Amarillo

    return red_objects_centers, grey_image_colored

# Cargar la imagen
image_path = 'C:\\Users\\angel\\Desktop\\AI\\Tareas\\imagenIslasRojas.png'
image = cv2.imread(image_path)

# Encontrar los objetos rojos y mostrarlos en su color original sobre fondo gris
red_objects_centers, result_image = find_red_objects(image)

# Imprimir las coordenadas de los centros de los objetos rojos detectados
for idx, center in enumerate(red_objects_centers):
    print(f"Centro del objeto rojo {idx+1}: {center}")

# Guardar la imagen resultante
output_image_path = 'C:\\Users\\angel\\Desktop\\AI\\Tareas\\detected_red_objects_on_grey.png'
cv2.imwrite(output_image_path, result_image)

# Mostrar la imagen resultante con los objetos rojos marcados
cv2.imshow('Red Objects on Grey', result_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

output_image_path
# Out:
# Centro del objeto rojo 1: (581, 624)
# Centro del objeto rojo 2: (328, 619)
# Centro del objeto rojo 3: (213, 617)
# Centro del objeto rojo 4: (607, 621)
# Centro del objeto rojo 5: (260, 615)
# Centro del objeto rojo 6: (223, 615)
# Centro del objeto rojo 7: (230, 613)
# Centro del objeto rojo 8: (174, 615)
# Centro del objeto rojo 9: (508, 608)
# Centro del objeto rojo 10: (482, 606)
# Centro del objeto rojo 11: (245, 608)
# Centro del objeto rojo 12: (368, 609)
# Centro del objeto rojo 13: (349, 608)
# Centro del objeto rojo 14: (386, 602)
# Centro del objeto rojo 15: (474, 603)
# Centro del objeto rojo 16: (231, 597)
# Centro del objeto rojo 17: (502, 591)
# Centro del objeto rojo 18: (491, 591)
# Centro del objeto rojo 19: (430, 609)
# Centro del objeto rojo 20: (276, 588)
# Centro del objeto rojo 21: (351, 586)
# Centro del objeto rojo 22: (335, 588)
# Centro del objeto rojo 23: (499, 583)
# Centro del objeto rojo 24: (476, 584)
# Centro del objeto rojo 25: (496, 576)
# Centro del objeto rojo 26: (234, 583)
# Centro del objeto rojo 27: (353, 573)
# Centro del objeto rojo 28: (533, 580)
# Centro del objeto rojo 29: (324, 571)
# Centro del objeto rojo 30: (477, 569)
# Centro del objeto rojo 31: (99, 572)
# Centro del objeto rojo 32: (290, 563)
# Centro del objeto rojo 33: (281, 563)
# Centro del objeto rojo 34: (306, 562)
# Centro del objeto rojo 35: (36, 554)
# Centro del objeto rojo 36: (278, 552)
# Centro del objeto rojo 37: (47, 541)
# Centro del objeto rojo 38: (262, 541)
# Centro del objeto rojo 39: (232, 542)
# Centro del objeto rojo 40: (480, 523)
# Centro del objeto rojo 41: (415, 527)
# Centro del objeto rojo 42: (507, 520)
# Centro del objeto rojo 43: (493, 518)
# Centro del objeto rojo 44: (245, 520)
# Centro del objeto rojo 45: (433, 518)
# Centro del objeto rojo 46: (605, 513)
# Centro del objeto rojo 47: (614, 512)
# Centro del objeto rojo 48: (483, 509)
# Centro del objeto rojo 49: (13, 508)
# Centro del objeto rojo 50: (511, 508)
# Centro del objeto rojo 51: (83, 507)
# Centro del objeto rojo 52: (391, 514)
# Centro del objeto rojo 53: (41, 508)
# Centro del objeto rojo 54: (615, 502)
# Centro del objeto rojo 55: (242, 503)
# Centro del objeto rojo 56: (484, 501)
# Centro del objeto rojo 57: (505, 499)
# Centro del objeto rojo 58: (254, 500)
# Centro del objeto rojo 59: (95, 497)
# Centro del objeto rojo 60: (31, 504)
# Centro del objeto rojo 61: (485, 494)
# Centro del objeto rojo 62: (291, 492)
# Centro del objeto rojo 63: (16, 491)
# Centro del objeto rojo 64: (514, 490)
# Centro del objeto rojo 65: (419, 489)
# Centro del objeto rojo 66: (488, 486)
# Centro del objeto rojo 67: (228, 486)
# Centro del objeto rojo 68: (121, 504)
# Centro del objeto rojo 69: (269, 484)
# Centro del objeto rojo 70: (524, 482)
# Centro del objeto rojo 71: (250, 479)
# Centro del objeto rojo 72: (593, 500)
# Centro del objeto rojo 73: (509, 476)
# Centro del objeto rojo 74: (291, 478)
# Centro del objeto rojo 75: (269, 474)
# Centro del objeto rojo 76: (552, 473)
# Centro del objeto rojo 77: (19, 472)
# Centro del objeto rojo 78: (584, 471)
# Centro del objeto rojo 79: (64, 483)
# Centro del objeto rojo 80: (570, 466)
# Centro del objeto rojo 81: (528, 465)
# Centro del objeto rojo 82: (577, 462)
# Centro del objeto rojo 83: (44, 474)
# Centro del objeto rojo 84: (544, 449)
# Centro del objeto rojo 85: (84, 470)
# Centro del objeto rojo 86: (240, 448)
# Centro del objeto rojo 87: (136, 448)
# Centro del objeto rojo 88: (247, 444)
# Centro del objeto rojo 89: (115, 444)
# Centro del objeto rojo 90: (150, 440)
# Centro del objeto rojo 91: (232, 442)
# Centro del objeto rojo 92: (531, 437)
# Centro del objeto rojo 93: (125, 437)
# Centro del objeto rojo 94: (547, 435)
# Centro del objeto rojo 95: (281, 436)
# Centro del objeto rojo 96: (538, 436)
# Centro del objeto rojo 97: (572, 432)
# Centro del objeto rojo 98: (563, 429)
# Centro del objeto rojo 99: (163, 430)
# Centro del objeto rojo 100: (549, 428)
# Centro del objeto rojo 101: (527, 426)
# Centro del objeto rojo 102: (257, 426)
# Centro del objeto rojo 103: (533, 425)
# Centro del objeto rojo 104: (281, 425)
# Centro del objeto rojo 105: (244, 424)
# Centro del objeto rojo 106: (171, 423)
# Centro del objeto rojo 107: (231, 422)
# Centro del objeto rojo 108: (214, 416)
# Centro del objeto rojo 109: (167, 416)
# Centro del objeto rojo 110: (495, 414)
# Centro del objeto rojo 111: (31, 428)
# Centro del objeto rojo 112: (568, 417)
# Centro del objeto rojo 113: (288, 410)
# Centro del objeto rojo 114: (273, 410)
# Centro del objeto rojo 115: (256, 412)
# Centro del objeto rojo 116: (227, 405)
# Centro del objeto rojo 117: (127, 406)
# Centro del objeto rojo 118: (279, 402)
# Centro del objeto rojo 119: (540, 408)
# Centro del objeto rojo 120: (256, 401)
# Centro del objeto rojo 121: (244, 401)
# Centro del objeto rojo 122: (526, 398)
# Centro del objeto rojo 123: (514, 399)
# Centro del objeto rojo 124: (338, 398)
# Centro del objeto rojo 125: (98, 398)
# Centro del objeto rojo 126: (114, 396)
# Centro del objeto rojo 127: (508, 392)
# Centro del objeto rojo 128: (138, 392)
# Centro del objeto rojo 129: (126, 391)
# Centro del objeto rojo 130: (277, 389)
# Centro del objeto rojo 131: (243, 390)
# Centro del objeto rojo 132: (262, 392)
# Centro del objeto rojo 133: (513, 384)
# Centro del objeto rojo 134: (62, 384)
# Centro del objeto rojo 135: (80, 385)
# Centro del objeto rojo 136: (107, 382)
# Centro del objeto rojo 137: (503, 378)
# Centro del objeto rojo 138: (289, 382)
# Centro del objeto rojo 139: (267, 378)
# Centro del objeto rojo 140: (94, 378)
# Centro del objeto rojo 141: (125, 375)
# Centro del objeto rojo 142: (406, 383)
# Centro del objeto rojo 143: (453, 383)
# Centro del objeto rojo 144: (69, 365)
# Centro del objeto rojo 145: (93, 365)
# Centro del objeto rojo 146: (540, 357)
# Centro del objeto rojo 147: (511, 358)
# Centro del objeto rojo 148: (404, 365)
# Centro del objeto rojo 149: (49, 364)
# Centro del objeto rojo 150: (189, 346)
# Centro del objeto rojo 151: (51, 341)
# Centro del objeto rojo 152: (66, 334)
# Centro del objeto rojo 153: (209, 333)
# Centro del objeto rojo 154: (193, 333)
# Centro del objeto rojo 155: (481, 346)
# Centro del objeto rojo 156: (168, 332)
# Centro del objeto rojo 157: (237, 345)
# Centro del objeto rojo 158: (176, 318)
# Centro del objeto rojo 159: (303, 317)
# Centro del objeto rojo 160: (319, 312)
# Centro del objeto rojo 161: (188, 311)
# Centro del objeto rojo 162: (138, 320)
# Centro del objeto rojo 163: (239, 298)
# Centro del objeto rojo 164: (606, 301)
# Centro del objeto rojo 165: (83, 303)
# Centro del objeto rojo 166: (584, 287)
# Centro del objeto rojo 167: (415, 285)
# Centro del objeto rojo 168: (221, 286)
# Centro del objeto rojo 169: (176, 290)
# Centro del objeto rojo 170: (255, 285)
# Centro del objeto rojo 171: (604, 283)
# Centro del objeto rojo 172: (16, 291)
# Centro del objeto rojo 173: (488, 286)
# Centro del objeto rojo 174: (584, 276)
# Centro del objeto rojo 175: (600, 273)
# Centro del objeto rojo 176: (244, 269)
# Centro del objeto rojo 177: (210, 262)
# Centro del objeto rojo 178: (581, 262)
# Centro del objeto rojo 179: (469, 261)
# Centro del objeto rojo 180: (448, 255)
# Centro del objeto rojo 181: (415, 255)
# Centro del objeto rojo 182: (204, 255)
# Centro del objeto rojo 183: (456, 251)
# Centro del objeto rojo 184: (444, 244)
# Centro del objeto rojo 185: (57, 250)
# Centro del objeto rojo 186: (387, 237)
# Centro del objeto rojo 187: (569, 239)
# Centro del objeto rojo 188: (457, 231)
# Centro del objeto rojo 189: (145, 244)
# Centro del objeto rojo 190: (189, 241)
# Centro del objeto rojo 191: (583, 224)
# Centro del objeto rojo 192: (25, 248)
# Centro del objeto rojo 193: (235, 229)
# Centro del objeto rojo 194: (245, 204)
# Centro del objeto rojo 195: (277, 202)
# Centro del objeto rojo 196: (465, 212)
# Centro del objeto rojo 197: (190, 200)
# Centro del objeto rojo 198: (32, 197)
# Centro del objeto rojo 199: (196, 194)
# Centro del objeto rojo 200: (496, 192)
# Centro del objeto rojo 201: (42, 190)
# Centro del objeto rojo 202: (27, 190)
# Centro del objeto rojo 203: (505, 189)
# Centro del objeto rojo 204: (222, 193)
# Centro del objeto rojo 205: (517, 186)
# Centro del objeto rojo 206: (408, 179)
# Centro del objeto rojo 207: (23, 182)
# Centro del objeto rojo 208: (504, 176)
# Centro del objeto rojo 209: (390, 171)
# Centro del objeto rojo 210: (439, 167)
# Centro del objeto rojo 211: (406, 166)
# Centro del objeto rojo 212: (476, 166)
# Centro del objeto rojo 213: (361, 163)
# Centro del objeto rojo 214: (427, 168)
# Centro del objeto rojo 215: (389, 162)
# Centro del objeto rojo 216: (498, 158)
# Centro del objeto rojo 217: (459, 164)
# Centro del objeto rojo 218: (76, 157)
# Centro del objeto rojo 219: (475, 155)
# Centro del objeto rojo 220: (442, 155)
# Centro del objeto rojo 221: (394, 155)
# Centro del objeto rojo 222: (281, 154)
# Centro del objeto rojo 223: (484, 153)
# Centro del objeto rojo 224: (374, 152)
# Centro del objeto rojo 225: (288, 152)
# Centro del objeto rojo 226: (13, 163)
# Centro del objeto rojo 227: (430, 151)
# Centro del objeto rojo 228: (504, 149)
# Centro del objeto rojo 229: (254, 149)
# Centro del objeto rojo 230: (268, 143)
# Centro del objeto rojo 231: (245, 141)
# Centro del objeto rojo 232: (510, 138)
# Centro del objeto rojo 233: (169, 137)
# Centro del objeto rojo 234: (578, 137)
# Centro del objeto rojo 235: (432, 137)
# Centro del objeto rojo 236: (59, 133)
# Centro del objeto rojo 237: (52, 130)
# Centro del objeto rojo 238: (592, 172)
# Centro del objeto rojo 239: (570, 129)
# Centro del objeto rojo 240: (479, 126)
# Centro del objeto rojo 241: (579, 124)
# Centro del objeto rojo 242: (489, 126)
# Centro del objeto rojo 243: (412, 121)
# Centro del objeto rojo 244: (420, 120)
# Centro del objeto rojo 245: (570, 118)
# Centro del objeto rojo 246: (317, 141)
# Centro del objeto rojo 247: (588, 119)
# Centro del objeto rojo 248: (294, 115)
# Centro del objeto rojo 249: (430, 114)
# Centro del objeto rojo 250: (281, 110)
# Centro del objeto rojo 251: (582, 107)
# Centro del objeto rojo 252: (248, 105)
# Centro del objeto rojo 253: (287, 96)
# Centro del objeto rojo 254: (313, 94)
# Centro del objeto rojo 255: (607, 95)
# Centro del objeto rojo 256: (619, 86)
# Centro del objeto rojo 257: (336, 84)
# Centro del objeto rojo 258: (342, 82)
# Centro del objeto rojo 259: (107, 82)
# Centro del objeto rojo 260: (597, 80)
# Centro del objeto rojo 261: (311, 82)
# Centro del objeto rojo 262: (104, 68)
# Centro del objeto rojo 263: (339, 65)
# Centro del objeto rojo 264: (17, 66)
# Centro del objeto rojo 265: (606, 61)
# Centro del objeto rojo 266: (420, 50)
# Centro del objeto rojo 267: (507, 46)
# Centro del objeto rojo 268: (500, 41)
# Centro del objeto rojo 269: (615, 37)
# Centro del objeto rojo 270: (606, 37)
# Centro del objeto rojo 271: (270, 57)
# Centro del objeto rojo 272: (348, 37)
# Centro del objeto rojo 273: (418, 35)
# Centro del objeto rojo 274: (295, 35)
# Centro del objeto rojo 275: (513, 35)
# Centro del objeto rojo 276: (231, 32)
# Centro del objeto rojo 277: (408, 31)
# Centro del objeto rojo 278: (308, 35)
# Centro del objeto rojo 279: (155, 28)
# Centro del objeto rojo 280: (301, 26)
# Centro del objeto rojo 281: (161, 59)
# Centro del objeto rojo 282: (24, 33)
# Centro del objeto rojo 283: (491, 33)
# Centro del objeto rojo 284: (503, 22)
# Centro del objeto rojo 285: (309, 22)
# Centro del objeto rojo 286: (361, 24)
# Centro del objeto rojo 287: (573, 26)
# Centro del objeto rojo 288: (443, 20)
# Centro del objeto rojo 289: (400, 15)
# 'C:\\Users\\angel\\Desktop\\AI\\Tareas\\detected_red_objects_on_grey.png'

# %% [markdown]
# ![Alt text](detected_red_objects_on_grey.png)
